# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import os
import re
import nltk
from src.loader import DataLoader
slack_data = data_loader.load_slack_data("path/to/slack_channel_data")
df = pd.read_json('all-week8/2022-10-09.json')
def load_data(path):
    df = pd.read_json(path)
    return df
    
data_loader = DataLoader()

df
def load_data(path):
    df = pd.read_json(path)
    return df
data_loader = DataLoader()
df = load_data('all-week8/2022-10-09.json')
number_of_users = df['user'].nunique()
print(f"Number of users: {number_of_users}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 9
#       7 import re
#       8 import nltk
# ----> 9 from src.loader import DataLoader
#      10 slack_data = data_loader.load_slack_data("path/to/slack_channel_data")
#      11 df = pd.read_json('all-week8/2022-10-09.json')
#
# ModuleNotFoundError: No module named 'src'

# %%
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.665339e+09  U03TEPYRM2P
# 1   message  channel_join  1.665341e+09  U03UH397319
# 2   message  channel_join  1.665341e+09  U03UUS0MZCZ
# 3   message  channel_join  1.665341e+09  U03V61VGQG0
# 4   message  channel_join  1.665341e+09  U03UG4Q7V42
# 5   message  channel_join  1.665341e+09  U03U1FNPEUX
# 6   message  channel_join  1.665341e+09  U03UG5VFN03
# 7   message  channel_join  1.665341e+09  U03UAKATQ22
# 8   message  channel_join  1.665341e+09  U03UKL27B0R
# 9   message  channel_join  1.665341e+09  U03UUR571A5
# 10  message  channel_join  1.665341e+09  U03V785NLSU
# 11  message  channel_join  1.665341e+09  U03V5Q9N516
# 12  message  channel_join  1.665341e+09  U03UJGP0C68
# 13  message  channel_join  1.665341e+09  U03TT5KEYCF
# 14  message  channel_join  1.665341e+09  U03UJN29Y4C
# 15  message  channel_join  1.665341e+09  U03U93GNNVB
# 16  message  channel_join  1.665341e+09  U03UHB8CXDY
# ...

# %%
df.shape
# Out:
# (50, 8)

# %%
def load_data(path):
    df = pd.read_json(path)
    return df

# %%
def load_data(path):
    df = pd.read_json(path)
    return df

df = load_data('all-week8/2022-10-09.json')

# %%
df
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.665339e+09  U03TEPYRM2P
# 1   message  channel_join  1.665341e+09  U03UH397319
# 2   message  channel_join  1.665341e+09  U03UUS0MZCZ
# 3   message  channel_join  1.665341e+09  U03V61VGQG0
# 4   message  channel_join  1.665341e+09  U03UG4Q7V42
# 5   message  channel_join  1.665341e+09  U03U1FNPEUX
# 6   message  channel_join  1.665341e+09  U03UG5VFN03
# 7   message  channel_join  1.665341e+09  U03UAKATQ22
# 8   message  channel_join  1.665341e+09  U03UKL27B0R
# 9   message  channel_join  1.665341e+09  U03UUR571A5
# 10  message  channel_join  1.665341e+09  U03V785NLSU
# 11  message  channel_join  1.665341e+09  U03V5Q9N516
# 12  message  channel_join  1.665341e+09  U03UJGP0C68
# 13  message  channel_join  1.665341e+09  U03TT5KEYCF
# 14  message  channel_join  1.665341e+09  U03UJN29Y4C
# 15  message  channel_join  1.665341e+09  U03U93GNNVB
# 16  message  channel_join  1.665341e+09  U03UHB8CXDY
# ...

# %%
number_of_users = df['user'].nunique()
print(f"Number of users: {number_of_users}")
# Out:
# Number of users: 50
